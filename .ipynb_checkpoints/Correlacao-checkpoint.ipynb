# %%
# generate related variables
from numpy import mean
from numpy import std
from numpy import cov
from numpy.random import randn
from numpy.random import seed
from pandas import read_excel
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import numpy as np

# %%
URL = "H:\\Users\\admin\\Projects\\Desafios\\DesafioIBM\\Arquivos\\registros-prod.xlsx"
df = read_excel(URL, engine='openpyxl')

# %%
# prepare data
x1 = df['QTD_CHOC']
x2 = df['VAR_1']
y  = df['PESO_BOMBOM']

# %%
# summarize
print('QTD_CHOC: mean=%.3f stdv=%.3f' % (mean(x1), std(x1)))
print('PESO_BOMBOM: mean=%.3f stdv=%.3f' % (mean(y), std(y)))
# plot
plt.scatter(x1, y, c=['red'])
plt.show()
# Out:
# QTD_CHOC: mean=291.265 stdv=45.137
# PESO_BOMBOM: mean=10.395 stdv=1.571

# %%
print('VAR_1: mean=%.3f stdv=%.3f' % (mean(x2), std(x2)))
print('PESO_BOMBOM: mean=%.3f stdv=%.3f' % (mean(y), std(y)))
# plot
plt.scatter(x2, y, c=['blue'])
plt.show()
# Out:
# VAR_1: mean=2.098 stdv=0.710
# PESO_BOMBOM: mean=10.395 stdv=1.571

# %%
# calculate covariance matrix
covariance = cov(x1, y)
print(covariance)
# Out:
# [[2041.45823691   31.05876956]
#  [  31.05876956    2.47191551]]

# %%
# calculate covariance matrix
covariance = cov(x2, y)
print(covariance)
# Out:
# [[0.5057564  0.35406015]
#  [0.35406015 2.47191551]]

# %%
# calculate Pearson's correlation
corr, _ = pearsonr(x1, y)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.437

# %%
# calculate Pearson's correlation
corr, _ = pearsonr(x2, y)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.317
